# %%
import pandas as pd
import datetime

# %%
# delimeter chi dinh cach chia moi cot
# cach set read_csv doc duoc la sep = '\t' for tab
# d_parser = lambda x: datetime.datetime.strptime(x,'%Y')
df = pd.read_csv('/home/van/Desktop/pandas_scipy_2020/pandas_mau/data/gapminder.tsv',
           sep='\t') #,parse_dates=['year'], date_parser=d_parser)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Why don't use pickle to save df?
# **Use pickle when:**
# - Have analysis pipeline and need to transfer output data into input anoter script (mang tinh temporary)
#
# **Use pandas df when:**
# - Longterm storage && work i=on mulitple languages to match

# %%
# looking for rows and cols -- xem header co khong check du so luong data
df.shape
# Out:
# (1704, 6)

# %%
# tell more about data (object data can call on itself)
# not display NaN value
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
# df attributes still call by filter
df.dtypes[df.dtypes == 'int64']
# Out:
# year    int64
# pop     int64
# dtype: object

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %% [markdown]
# ##  looking at columns in data

# %%
df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
# select 1 col --> series
df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
# select multiple cols --> dataframe
df[['country','pop']]
# Out:
#           country       pop
# 0     Afghanistan   8425333
# 1     Afghanistan   9240934
# 2     Afghanistan  10267083
# 3     Afghanistan  11537966
# 4     Afghanistan  13079460
# ...           ...       ...
# 1699     Zimbabwe   9216418
# 1700     Zimbabwe  10704340
# 1701     Zimbabwe  11404948
# 1702     Zimbabwe  11926563
# 1703     Zimbabwe  12311143
#
# [1704 rows x 2 columns]

# %% [markdown]
# ## Looking at rows in data

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
# offset using slice
df.loc[0:3,'country':'year']
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967

# %%
# subset picking specific rows and cols
df.loc[[1,2,3],['country','year']]
# Out:
#        country  year
# 1  Afghanistan  1957
# 2  Afghanistan  1962
# 3  Afghanistan  1967

# %%
# iloc su dung cho index nen goi so am duoc
# loc su dung text nen khong su dung so am duoc
df.iloc[-1]
# Out:
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp       43.487000
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %% [markdown]
# ## subsetting rows and columns

# %%
flit = df['country']=='Zimbabwe'
flit_1 = df['year'] >1990

# %%
# filter out Zimbabwe and year > 1990
df.loc[flit&flit_1]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
# same things but the vao luon notice parenthesis
df.loc[(df['country']=='Zimbabwe') & (df['year'] >1990)]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
df.sort_values(by=['country','year'],ascending=[True,False])
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 11    Afghanistan      Asia  2007   43.828  31889923  974.580338
# 10    Afghanistan      Asia  2002   42.129  25268405  726.734055
# 9     Afghanistan      Asia  1997   41.763  22227415  635.341351
# 8     Afghanistan      Asia  1992   41.674  16317921  649.341395
# 7     Afghanistan      Asia  1987   40.822  13867957  852.395945
# ...           ...       ...   ...      ...       ...         ...
# 1696     Zimbabwe    Africa  1972   55.635   5861135  799.362176
# 1695     Zimbabwe    Africa  1967   53.995   4995432  569.795071
# 1694     Zimbabwe    Africa  1962   52.358   4277736  527.272182
# 1693     Zimbabwe    Africa  1957   50.469   3646340  518.764268
# 1692     Zimbabwe    Africa  1952   48.451   3080907  406.884115
#
# [1704 rows x 6 columns]

# %% [markdown]
# ## For every year what is the lifeExp in average?

# %%
# groupby year for every la dau hieu
df.groupby(by='year')['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
import numpy as np

# %%
# phai co them [] moi the hien nhieu ham duoc
df.groupby(by='year')['lifeExp'].agg(['mean','sum',np.std])
# Out:
#            mean         sum        std
# year
# 1952  49.057620  6966.18200  12.225956
# 1957  51.507401  7314.05096  12.231286
# 1962  53.609249  7612.51336  12.097245
# 1967  55.678290  7906.31712  11.718858
# 1972  57.647386  8185.92888  11.381953
# 1977  59.570157  8458.96236  11.227229
# 1982  61.533197  8737.71400  10.770618
# 1987  63.212613  8976.19100  10.556285
# 1992  64.160338  9110.76800  11.227380
# 1997  65.014676  9232.08400  11.559439
# 2002  65.694923  9328.67900  12.279823
# 2007  67.007423  9515.05400  12.073021

# %% [markdown]
# ## How does the lifeExp and gdpcap change over year and continent?

# %%
df.groupby(by=['year','continent'])[['lifeExp','gdpPercap']].agg(['mean','sum'])
# Out:
#                   lifeExp                 gdpPercap
#                      mean         sum          mean            sum
# year continent
# 1952 Africa     39.135500  2035.04600   1252.572466   65133.768223
#      Americas   53.279840  1331.99600   4079.062552  101976.563805
#      Asia       46.314394  1528.37500   5195.484004  171450.972133
#      Europe     64.408500  1932.25500   5661.057435  169831.723043
#      Oceania    69.255000   138.51000  10298.085650   20596.171300
# 1957 Africa     41.266346  2145.85000   1385.236062   72032.275237
#      Americas   55.960280  1399.00700   4616.043733  115401.093329
#      Asia       49.318544  1627.51196   5787.732940  190995.187018
#      Europe     66.703067  2001.09200   6963.012816  208890.384478
#      Oceania    70.295000   140.59000  11598.522455   23197.044910
# 1962 Africa     43.319442  2252.61100   1598.078825   83100.098892
#      Americas   58.398760  1459.96900   4901.541870  122538.546760
# ...

# %%
grouped = df.groupby(by=['year','continent'])[['lifeExp','gdpPercap']].agg('mean')

# %%
grouped_reset = grouped.reset_index()

# %%
grouped_reset
# Out:
#     year continent    lifeExp     gdpPercap
# 0   1952    Africa  39.135500   1252.572466
# 1   1952  Americas  53.279840   4079.062552
# 2   1952      Asia  46.314394   5195.484004
# 3   1952    Europe  64.408500   5661.057435
# 4   1952   Oceania  69.255000  10298.085650
# 5   1957    Africa  41.266346   1385.236062
# 6   1957  Americas  55.960280   4616.043733
# 7   1957      Asia  49.318544   5787.732940
# 8   1957    Europe  66.703067   6963.012816
# 9   1957   Oceania  70.295000  11598.522455
# 10  1962    Africa  43.319442   1598.078825
# 11  1962  Americas  58.398760   4901.541870
# 12  1962      Asia  51.563223   5729.369625
# 13  1962    Europe  68.539233   8365.486814
# 14  1962   Oceania  71.085000  12696.452430
# 15  1967    Africa  45.334538   2050.363801
# 16  1967  Americas  60.410920   5668.253496
# 17  1967      Asia  54.663640   5971.173374
# 18  1967    Europe  69.737600  10143.823757
# 19  1967   Oceania  71.310000  14495.021790
# ...
